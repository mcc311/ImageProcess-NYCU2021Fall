# %%
import numpy as np
from PIL import Image

images = [Image.open(x) for x in ['night.jpg', 'edge_average.jpg', 'edge_gaussian.jpg']]
widths, heights = zip(*(i.size for i in images))

frame_size = 1
total_width = sum(widths)+ frame_size * (len(images) - 1)
max_height = max(heights)

new_im = Image.new('RGB', (total_width, max_height), color=(255, 255, 255))

x_offset = 0
for im in images:
    new_im.paste(im, (x_offset,0))
    x_offset += im.size[0] + frame_size
new_im.save('test.jpg')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 50
A = np.linspace(-np.pi, np.pi, N)
B = np.linspace(-np.pi, np.pi, N)

np.apply_along_axis(lambda b: plt.plot(A, np.sin(A+b)*b),0, B.reshape(1,-1))
# Out:
# array([[<matplotlib.lines.Line2D object at 0x7fc02b214430>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2147c0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b214af0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b214e20>,
#         <matplotlib.lines.Line2D object at 0x7fc02b21f1f0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b21f580>,
#         <matplotlib.lines.Line2D object at 0x7fc02b21f910>,
#         <matplotlib.lines.Line2D object at 0x7fc02b21fbe0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b21ff70>,
#         <matplotlib.lines.Line2D object at 0x7fc02b22b340>,
#         <matplotlib.lines.Line2D object at 0x7fc02b18e130>,
#         <matplotlib.lines.Line2D object at 0x7fc02b22ba00>,
#         <matplotlib.lines.Line2D object at 0x7fc02b22bd90>,
#         <matplotlib.lines.Line2D object at 0x7fc02b263160>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2634f0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b263880>,
#         <matplotlib.lines.Line2D object at 0x7fc02b263c10>,
#         <matplotlib.lines.Line2D object at 0x7fc02b263fa0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b26d370>,
#         <matplotlib.lines.Line2D object at 0x7fc02b26d700>,
#         <matplotlib.lines.Line2D object at 0x7fc02b26da90>,
#         <matplotlib.lines.Line2D object at 0x7fc02b26de20>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2791f0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b279580>,
#         <matplotlib.lines.Line2D object at 0x7fc02b279910>,
#         <matplotlib.lines.Line2D object at 0x7fc02b279ca0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b286070>,
#         <matplotlib.lines.Line2D object at 0x7fc02b286400>,
#         <matplotlib.lines.Line2D object at 0x7fc02b286790>,
#         <matplotlib.lines.Line2D object at 0x7fc02b286b20>,
#         <matplotlib.lines.Line2D object at 0x7fc02b286eb0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b28f280>,
#         <matplotlib.lines.Line2D object at 0x7fc02b28f610>,
#         <matplotlib.lines.Line2D object at 0x7fc02b28f9a0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b28fd30>,
#         <matplotlib.lines.Line2D object at 0x7fc02b29d100>,
#         <matplotlib.lines.Line2D object at 0x7fc02b29d490>,
#         <matplotlib.lines.Line2D object at 0x7fc02b29d820>,
#         <matplotlib.lines.Line2D object at 0x7fc02b29dbb0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b29df40>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2a8310>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2a86a0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2a8a30>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2a8dc0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2b5190>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2b5520>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2b58b0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2b5c40>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2b5fd0>,
#         <matplotlib.lines.Line2D object at 0x7fc02b2bf3a0>]], dtype=object)
